# %%
import pandas as pd

# %%
draft = pd.read_csv("2015_draft_data.csv")
draft.head()
# Out:
#    draft_id      draft_Player  draft_All_NBA  draft_All_Star  draft_Draft_Yr  \
# 0       274  Chris McCullough              0               0            2015
# 1       275   Pat Connaughton              0               0            2015
# 2       573      Kevon Looney              0               0            2015
# 3       859     Jarell Martin              0               0            2015
# 4       896   Marcus Thornton              0               0            2015
#
#    draft_Pk draft_Team                         draft_College  draft_Yrs  \
# 0        29        NJN                   Syracuse University          1
# 1        41        NJN              University of Notre Dame          1
# 2        30        GSW  University of California Los Angeles          1
# 3        25        MEM            Louisiana State University          1
# 4        45        BOS             College of William & Mary          0
#
#    draft_Games        ...         draft_Executive  \
# ...

# %%
nba = pd.read_csv("2016_nba_data.csv")
nba.head()
# Out:
#    nba_Year nba_Tm      nba_Player  nba_Age  nba_G  nba_MP  nba_PER  nba_TS%  \
# 0      2016    ATL    Paul Millsap       30      9     312     22.5    0.581
# 1      2016    ORL  Victor Oladipo       23      8     308     14.5    0.454
# 2      2016    ORL   Evan Fournier       23      8     302     15.4    0.580
# 3      2016    IND     George Hill       29      8     299     16.3    0.602
# 4      2016    POR  Damian Lillard       25      8     293     26.3    0.602
#
#    nba_3PAr  nba_FTr       ...         nba_D-WORP  nba_Adjusted WORP  \
# 0     0.333    0.423       ...                5.7               15.7
# 1     0.313    0.134       ...                3.9                3.9
# 2     0.408    0.208       ...               -2.8                3.7
# 3     0.495    0.363       ...                3.0               10.8
# 4     0.424    0.242       ...               -5.1               15.0
#
#    nba_Estimated Position  nba_BBRef Pos  nba_Age on Feb 1  \
# ...

# %%
df = pd.merge(draft, nba, how = "inner",
              left_on = "draft_Player", right_on = "nba_Player")
df
# Out:
#     draft_id             draft_Player  draft_All_NBA  draft_All_Star  \
# 0        275          Pat Connaughton              0               0
# 1        896          Marcus Thornton              0               0
# 2        897             Terry Rozier              0               0
# 3        898              R.J. Hunter              0               0
# 4        899            Jordan Mickey              0               0
# 5        928               Sam Dekker              0               0
# 6        929         Montrezl Harrell              0               0
# 7       1044               Trey Lyles              0               0
# 8       1211          Justin Anderson              0               0
# 9       1440             Jerian Grant              0               0
# 10      1450       Karl-Anthony Towns              0               0
# 11      1533             Bobby Portis              0               0
# 12      1871          Stanley Johnson              0               0
# ...
