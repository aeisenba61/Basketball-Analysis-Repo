# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
os.chdir("C:/Users/Cynthia/Desktop/Bootcamp_Github/Basketball-Analysis-Repo/ml_logistic")
data = pd.read_csv("../data/clean/draft_nba.csv")
data.columns.get_values().tolist()
# Out:
# ['draft_Player',
#  'draft_All_NBA',
#  'draft_All.Star',
#  'draft_Draft_Yr',
#  'draft_Pk',
#  'draft_Team',
#  'draft_College',
#  'draft_Yrs',
#  'draft_Games',
#  'draft_Minutes.Played',
#  'draft_PTS',
#  'draft_TRB',
#  'draft_AST',
#  'draft_FG_Percentage',
#  'draft_TP_Percentage',
#  'draft_FT_Percentage',
#  'draft_Minutes.per.Game',
#  'draft_Points.per.Game',
#  'draft_TRB.per.game',
#  'draft_Assits.per.Game',
#  'draft_Win.Share',
#  'draft_WS_per_game',
#  'draft_BPM',
#  'draft_VORP',
#  'draft_Executive',
#  'draft_Tenure',
#  'draft_Exec_ID',
#  'draft_Exec_draft_exp',
#  'draft_attend_college',
#  'draft_first_year',
#  'draft_second_year',
#  'draft_third_year',
#  'draft_fourth_year',
#  'draft_fifth_year',
#  'nba_Year',
#  'nba_Tm',
#  'nba_Player',
#  'nba_Age',
#  'nba_G',
#  'nba_MP',
#  'nba_PER',
#  'nba_TS%',
#  'nba_3PAr',
#  'nba_FTr',
#  'nba_ORB%',
#  'nba_DRB%',
#  'nba_TRB%',
#  'nba_AST%',
#  'nba_STL%',
#  'nba_BLK%',
#  'nba_TOV%',
#  'nba_USG%',
#  'nba_OWS',
#  'nba_DWS',
#  'nba_WS',
#  'nba_WS/48',
#  'nba_OBPM',
#  'nba_DBPM',
#  'nba_BPM',
#  'nba_VORP',
#  'nba_OWS/48',
#  'nba_DWS/48',
#  'nba_Shot%',
#  'nba_Player ID',
#  'nba_Team Mar',
#  'nba_Team MP',
#  'nba_Team Gm',
#  'nba_Year 3PAr',
#  'nba_Team TS%',
#  'nba_Tm USG',
#  'nba_Tm TS W/O Plyr',
#  'nba_Reb/Vers',
#  'nba_Defense',
#  'nba_Val/Shot',
#  'nba_Offense',
#  'nba_MPG + Int',
#  'nba_RAW SPM',
#  'nba_%Min',
#  'nba_RAW Contrib',
#  'nba_Tm Sum',
#  'nba_Tm Adj',
#  'nba_BPM.1',
#  'nba_StdErr',
#  'nba_Contrib',
#  'nba_VORP.1',
#  'nba_Reb/Vers.1',
#  'nba_Val/Shot.1',
#  'nba_Offense.1',
#  'nba_Defense.1',
#  'nba_MPG',
#  'nba_Raw OBPM',
#  'nba_Contrib.1',
#  'nba_Tm Ortg',
#  'nba_Tm Sum.1',
#  'nba_Tm Adj.1',
#  'nba_Tm DRtg',
#  'nba_OBPM.1',
#  'nba_OStdErr',
#  'nba_Ocontrib',
#  'nba_OVORP',
#  'nba_DBPM.1',
#  'nba_DStdErr',
#  'nba_Dcontrib',
#  'nba_DVORP',
#  'nba_Sum SPM',
#  'nba_%Min.1',
#  'nba_MPG.1',
#  'nba_ReMPG',
#  'nba_BPM.2',
#  'nba_Contrib.2',
#  'nba_VORP.2',
#  'nba_VORP-Gm',
#  'nba_O-BPM',
#  'nba_Ocontrib.1',
#  'nba_OVORP.1',
#  'nba_OVORP-Gm',
#  'nba_D-BPM',
#  'nba_Dcontrib.1',
#  'nba_DVORP.1',
#  'nba_DVORP-Gm',
#  'nba_Production',
#  'nba_Prod-Gm',
#  'nba_Exp BPM',
#  'nba_TrueTalentBPM',
#  'nba_Exp%Min',
#  'nba_TrueTalentVORP',
#  'nba_TrueSalary',
#  'nba_TrueTimeVORP',
#  'nba_Adjusted Production',
#  'nba_WORP',
#  'nba_O-WORP',
#  'nba_D-WORP',
#  'nba_Adjusted WORP',
#  'nba_Estimated Position',
#  'nba_BBRef Pos',
#  'nba_Age on Feb 1',
#  'nba_Yrs Experience',
#  'nba_Height',
#  'nba_Weight',
#  'nba_Rounded Position',
#  'nba_Rounded Age',
#  'Roster',
#  'Traded']

# %%
pred1 = ["draft_All_NBA",
         "draft_All.Star",
         "draft_Pk",
         "draft_Games",
         "draft_Minutes.Played",
         "draft_Minutes.per.Game",
         "draft_Points.per.Game",
         "draft_Win.Share",
         "draft_WS_per_game",
         "draft_attend_college"]

# %%
from sklearn.model_selection import KFold
