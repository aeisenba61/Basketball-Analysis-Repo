# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from string import ascii_letters
sns.set(style='white', context='notebook', palette='deep')

# %matplotlib inline

from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.cross_validation import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
#Read in CSV
nba_df = pd.read_csv('draft_nba.csv')
nba_df
# Out:
#                draft_Player  draft_All_NBA  draft_All.Star  draft_Draft_Yr  \
# 0            Speedy Claxton              0               0            2000
# 1              Mark Karcher              0               0            2000
# 2            Stromile Swift              0               0            2000
# 3           Jamaal Magloire              0               0            2000
# 4             Erick Barkley              0               0            2000
# 5           Jake Tsakalidis              0               0            2000
# 6            Joel Przybilla              0               0            2000
# 7            Eduardo Najera              0               0            2000
# 8           Mamadou N'Diaye              0               0            2000
# 9            Dan McClintock              0               0            2000
# 10              Etan Thomas              0               0            2000
# 11               Dan Langhi              0               0            2000
# 12             Pete Mickeal              0               0            2000
# 13            Primoz Brezec              0               0            2000
# 14             Jaquay Walls              0               0            2000
# 15             Darius Miles              0               0            2000
# 16       Quentin Richardson              0               0            2000
# 17              Marko Jaric              0               0            2000
# 18             Michael Redd              1               1            2000
# 19            Jason Collier              0               0            2000
# 20               Jason Hart              0               0            2000
# 21             Chris Porter              0               0            2000
# 22            Hedo Turkoglu              0               0            2000
# 23             Jabari Smith              0               0            2000
# 24          Morris Peterson              0               0            2000
# 25          DeeAndre Hulett              0               0            2000
# 26          Chris Carrawell              0               0            2000
# 27           Cory Hightower              0               0            2000
# 28             Marcus Fizer              0               0            2000
# 29               Chris Mihm              0               0            2000
# ..                      ...            ...             ...             ...
# 859           Bruno Caboclo              0               0            2014
# 860         DeAndre Daniels              0               0            2014
# 861           Xavier Thames              0               0            2014
# 862           Julius Randle              0               0            2014
# 863           P.J. Hairston              0               0            2014
# 864          Semaj Christon              0               0            2014
# 865            Nik Stauskas              0               0            2014
# 866        Cleanthony Early              0               0            2014
# 867  Thanasis Antetokounmpo              0               0            2014
# 868           Kyle Anderson              0               0            2014
# 869            Jordan McRae              0               0            2014
# 870          Cory Jefferson              0               0            2014
# 871            Aaron Gordon              0               0            2014
# 872             Dario Saric              0               0            2014
# 873             T.J. Warren              0               0            2014
# 874             Tyler Ennis              0               0            2014
# 875       Bogdan Bogdanovic              0               0            2014
# 876              Alec Brown              0               0            2014
# 877             Joel Embiid              0               0            2014
# 878           Elfrid Payton              0               0            2014
# 879          K.J. McDaniels              0               0            2014
# 880            Jerami Grant              0               0            2014
# 881              Russ Smith              0               0            2014
# 882          Vasilije Micic              0               0            2014
# 883        Nemanja Dangubic              0               0            2014
# 884            Mitch McGary              0               0            2014
# 885            Josh Huestis              0               0            2014
# 886          Doug McDermott              0               0            2014
# 887            Nikola Jokic              0               0            2014
# 888        Roy Devyn Marble              0               0            2014
#
#      draft_Pk draft_Team                         draft_College  draft_Yrs  \
# 0          20        PHI                    Hofstra University          7
# 1          48        PHI                     Temple University          0
# 2           2        MEM            Louisiana State University          9
# 3          19        NOH                University of Kentucky         12
# 4          28        POR                 St. John's University          2
# 5          25        PHO                                     0          7
# 6           9        HOU               University of Minnesota         13
# 7          38        HOU                University of Oklahoma         12
# 8          26        DEN                     Auburn University          5
# 9          53        DEN           Northern Arizona University          1
# 10         12        DAL                   Syracuse University          9
# 11         31        DAL                 Vanderbilt University          4
# 12         58        DAL              University of Cincinnati          0
# 13         27        IND                                     0          8
# 14         56        IND                University of Colorado          0
# 15          3        LAC                                     0          7
# 16         18        LAC                     DePaul University         13
# 17         30        LAC                                     0          7
# 18         43        MIL                 Ohio State University         12
# 19         15        MIL       Georgia Institute of Technology          5
# 20         49        MIL                   Syracuse University          9
# 21         55        GSW                     Auburn University          1
# 22         16        SAC                                     0         15
# 23         45        SAC            Louisiana State University          4
# 24         21        TOR             Michigan State University         11
# 25         46        TOR               College of the Sequoias          0
# 26         41        SAS                       Duke University          0
# 27         54        SAS        Indian Hills Community College          0
# 28          4        CHI                 Iowa State University          6
# 29          7        CHI         University of Texas at Austin          8
# ..        ...        ...                                   ...        ...
# 859        20        TOR                                     0          2
# 860        37        TOR             University of Connecticut          0
# 861        59        TOR            San Diego State University          0
# 862         7        LAL                University of Kentucky          2
# 863        26        MIA          University of North Carolina          2
# 864        55        MIA                     Xavier University          0
# 865         8        SAC                University of Michigan          2
# 866        34        NYK              Wichita State University          2
# 867        51        NYK                                     0          1
# 868        30        SAS  University of California Los Angeles          2
# 869        58        SAS               University of Tennessee          1
# 870        60        SAS                     Baylor University          2
# 871         4        ORL                 University of Arizona          2
# 872        12        ORL                                     0          0
# 873        14        PHO       North Carolina State University          2
# 874        18        PHO                   Syracuse University          2
# 875        27        PHO                                     0          0
# 876        50        PHO     University of Wisconsin-Green Bay          0
# 877         3        PHI                  University of Kansas          0
# 878        10        PHI  University of Louisiana at Lafayette          2
# 879        32        PHI                    Clemson University          2
# 880        39        PHI                   Syracuse University          2
# 881        47        PHI              University of Louisville          2
# 882        52        PHI                                     0          0
# 883        54        PHI                                     0          0
# 884        21        OKC                University of Michigan          2
# 885        29        OKC                   Stanford University          1
# 886        11        DEN                  Creighton University          2
# 887        41        DEN                                     0          1
# 888        56        DEN                    University of Iowa          2
#
#      draft_Games  draft_Minutes.Played   ...    nba_ORB  nba_DRB  nba_TRB  \
# 0            334                  8548   ...        NaN      NaN      NaN
# 1              0                     0   ...        NaN      NaN      NaN
# 2            547                 10804   ...      109.0    175.0    284.0
# 3            680                 14621   ...      103.0    192.0    295.0
# 4             27                   266   ...        0.0      3.0      3.0
# 5            315                  5005   ...       83.0    159.0    242.0
# 6            592                 11733   ...       29.0     42.0     71.0
# 7            619                 11213   ...       41.0     54.0     95.0
# 8             69                   858   ...        1.0      1.0      2.0
# 9              6                    58   ...       10.0      7.0     17.0
# 10           409                  7084   ...        NaN      NaN      NaN
# 11           133                  1253   ...       13.0     28.0     41.0
# 12             0                     0   ...        NaN      NaN      NaN
# 13           342                  6192   ...        NaN      NaN      NaN
# 14             0                     0   ...        NaN      NaN      NaN
# 15           446                 11730   ...      127.0    350.0    477.0
# 16           783                 20785   ...      105.0    152.0    257.0
# 17           447                 11246   ...        NaN      NaN      NaN
# 18           629                 20104   ...        3.0      1.0      4.0
# 19           151                  2178   ...       12.0     25.0     37.0
# 20           341                  5289   ...        0.0      0.0      0.0
# 21            51                  1147   ...       89.0    100.0    189.0
# 22           997                 26695   ...       49.0    161.0    210.0
# 23           108                  1063   ...        1.0      7.0      8.0
# 24           711                 19366   ...      112.0    147.0    259.0
# 25             0                     0   ...        NaN      NaN      NaN
# 26             0                     0   ...        NaN      NaN      NaN
# 27             0                     0   ...        NaN      NaN      NaN
# 28           289                  6032   ...       76.0    237.0    313.0
# 29           436                  8758   ...      106.0    174.0    280.0
# ..           ...                   ...   ...        ...      ...      ...
# 859           14                    66   ...        1.0      1.0      2.0
# 860            0                     0   ...        NaN      NaN      NaN
# 861            0                     0   ...        NaN      NaN      NaN
# 862           82                  2300   ...        0.0      0.0      0.0
# 863          111                  2000   ...       22.0     70.0     92.0
# 864            0                     0   ...        NaN      NaN      NaN
# 865          146                  2936   ...       11.0     77.0     88.0
# 866           56                   801   ...       22.0     75.0     97.0
# 867            2                     6   ...        NaN      NaN      NaN
# 868          111                  1603   ...        5.0     67.0     72.0
# 869           22                   195   ...        NaN      NaN      NaN
# 870           58                   581   ...       47.0     98.0    145.0
# 871          125                  2660   ...       46.0    123.0    169.0
# 872            0                     0   ...        NaN      NaN      NaN
# 873           87                  1684   ...       41.0     44.0     85.0
# 874           79                  1065   ...        7.0     28.0     35.0
# 875            0                     0   ...        NaN      NaN      NaN
# 876            0                     0   ...        NaN      NaN      NaN
# 877            0                     0   ...        NaN      NaN      NaN
# 878          155                  4634   ...      107.0    242.0    349.0
# 879           99                  1587   ...       65.0    135.0    200.0
# 880          142                  3443   ...       49.0    149.0    198.0
# 881           27                   131   ...        1.0      5.0      6.0
# 882            0                     0   ...        NaN      NaN      NaN
# 883            0                     0   ...        NaN      NaN      NaN
# 884           52                   557   ...       53.0    112.0    165.0
# 885            5                    55   ...        NaN      NaN      NaN
# 886          117                  2182   ...        6.0     37.0     43.0
# 887           80                  1733   ...        NaN      NaN      NaN
# 888           44                   457   ...        NaN      NaN      NaN
#
#      nba_AST  nba_STL  nba_BLK  nba_TOV  nba_PF  nba_PTS  Traded
# 0        NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 1        NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 2       28.0     62.0     82.0     64.0   160.0    391.0     0.0
# 3       27.0     18.0     78.0     61.0   139.0    339.0     1.0
# 4        6.0      2.0      0.0      5.0     2.0     19.0     0.0
# 5       19.0     10.0     55.0     66.0   137.0    256.0     0.0
# 6        2.0      3.0     30.0     13.0    56.0     27.0     1.0
# 7       27.0     13.0      8.0     17.0    48.0    131.0     1.0
# 8        0.0      0.0      0.0      0.0     3.0      4.0     1.0
# 9        1.0      0.0      2.0      3.0    11.0     18.0     0.0
# 10       NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 11       4.0      7.0      1.0      8.0    16.0     90.0     1.0
# 12       NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 13       NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 14       NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 15      99.0     51.0    125.0    147.0   191.0    761.0     0.0
# 16      62.0     42.0      7.0     64.0    98.0    613.0     0.0
# 17       NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 18       1.0      1.0      0.0      1.0     2.0     13.0     0.0
# 19       6.0      2.0      3.0     11.0    27.0     71.0     1.0
# 20       1.0      0.0      0.0      2.0     0.0      2.0     0.0
# 21      61.0     45.0      6.0     59.0   111.0    440.0     0.0
# 22      69.0     52.0     24.0     55.0   139.0    391.0     0.0
# 23       6.0      4.0      0.0      3.0     7.0     26.0     0.0
# 24     105.0     63.0     20.0     78.0   164.0    747.0     0.0
# 25       NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 26       NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 27       NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 28      76.0     30.0     19.0    124.0   175.0    683.0     0.0
# 29      16.0     20.0     53.0     80.0   156.0    446.0     1.0
# ..       ...      ...      ...      ...     ...      ...     ...
# 859      0.0      0.0      1.0      4.0     3.0     10.0     0.0
# 860      NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 861      NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 862      0.0      0.0      0.0      1.0     1.0      2.0     0.0
# 863     21.0     21.0     13.0     22.0    61.0    254.0     1.0
# 864      NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 865     67.0     20.0     17.0     40.0    92.0    319.0     0.0
# 866     36.0     24.0     12.0     40.0    57.0    210.0     0.0
# 867      NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 868     28.0     15.0      7.0     10.0    28.0     74.0     0.0
# 869      NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 870     16.0     10.0     21.0     20.0    61.0    183.0     1.0
# 871     33.0     21.0     22.0     38.0    83.0    243.0     0.0
# 872      NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 873     25.0     18.0      9.0     27.0    51.0    245.0     0.0
# 874     73.0     18.0      5.0     42.0    36.0    121.0     1.0
# 875      NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 876      NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 877      NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 878    533.0    142.0     20.0    203.0   193.0    731.0     1.0
# 879     72.0     44.0     70.0    105.0   126.0    487.0     1.0
# 880     79.0     40.0     68.0     85.0   144.0    411.0     0.0
# 881      8.0      3.0      0.0     12.0    13.0     30.0     1.0
# 882      NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 883      NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 884     14.0     16.0     16.0     31.0    72.0    201.0     0.0
# 885      NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 886      6.0      4.0      1.0     17.0    29.0    109.0     1.0
# 887      NaN      NaN      NaN      NaN     NaN      NaN     NaN
# 888      NaN      NaN      NaN      NaN     NaN      NaN     NaN
#
# [889 rows x 93 columns]

# %%
clean_data1 = nba_df.dropna(subset = ['nba_VORP']).reset_index(drop=True)

# %%
# Only want the important draft information to predict what nba_VORP might be
important_data = ["nba_VORP",
            "draft_Pk",
            "draft_Games",
            "draft_Minutes.Played",
            "draft_PTS",
            "draft_TRB",
            "draft_AST",
            "draft_FG_Percentage",
            "draft_TP_Percentage",
            "draft_FT_Percentage",
            "draft_Minutes.per.Game",
            "draft_Points.per.Game",
            "draft_TRB.per.game",
            "draft_Assits.per.Game",
            "draft_Win.Share",
            "draft_WS_per_game",
            "draft_BPM",
            "draft_VORP",
            "draft_attend_college",
            ]

# %%
clean_data = clean_data1[important_data]
clean_data.head()
# Out:
#    nba_VORP  draft_Pk  draft_Games  draft_Minutes.Played  draft_PTS  \
# 0       0.2         2          547                 10804       4582
# 1      -0.2        19          680                 14621       4917
# 2       0.0        28           27                   266         77
# 3      -0.4        25          315                  5005       1497
# 4      -0.1         9          592                 11733       2293
#
#    draft_TRB  draft_AST  draft_FG_Percentage  draft_TP_Percentage  \
# 0       2535        275                0.473                0.074
# 1       4408        386                0.480                0.000
# 2         21         40                0.356                0.267
# 3       1238        101                0.490                0.000
# 4       3665        256                0.552                0.000
#
#    draft_FT_Percentage  draft_Minutes.per.Game  draft_Points.per.Game  \
# 0                0.699                    19.8                    8.4
# 1                0.639                    21.5                    7.2
# 2                0.900                     9.9                    2.9
# 3                0.657                    15.9                    4.8
# 4                0.557                    19.8                    3.9
#
#    draft_TRB.per.game  draft_Assits.per.Game  draft_Win.Share  \
# 0                 4.6                    0.5             21.3
# 1                 6.5                    0.6             27.7
# 2                 0.8                    1.5              0.2
# 3                 3.9                    0.3              9.9
# 4                 6.2                    0.4             23.0
#
#    draft_WS_per_game  draft_BPM  draft_VORP  draft_attend_college
# 0              0.095       -1.9         0.2                     1
# 1              0.091       -2.9        -3.3                     1
# 2              0.027       -3.8        -0.1                     1
# 3              0.095       -3.1        -1.3                     0
# 4              0.094       -0.9         3.3                     1

# %%
X = clean_data.iloc[:,1:]
y = clean_data.nba_VORP.values
print(X.shape, y.shape)
# Out:
# (648, 18) (648,)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
from sklearn.cross_validation import train_test_split

X_train , X_test , y_train , y_test = train_test_split(X ,y, test_size = 0.10,random_state =2)

# %%
reg.fit(X_train, y_train)
reg.score(X_test, y_test)
# Out:
# 0.51794724931620695

# %%
#try to boost the score some
from sklearn import ensemble
clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
          learning_rate = 0.1, loss = 'ls')

# %%
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.6303815724289219

# %%
#Look at correlation heatmap to indicate correlation
def correlation_heat_map(clean_data):
    corrs1 = clean_data.corr()

    # Set fig size
    fig, ax = plt.subplots(figsize=(12,10))

    # Hide upper right triangle
    mask = np.zeros_like(corrs1, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    # Plot the heatmap with seaborn.
    ax = sns.heatmap(corrs1, mask=mask, annot=True)

    # Resize labels
    ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=10, rotation=90)
    ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=10, rotation=0)


    plt.show()
    
correlation_heat_map(clean_data)

# %%
#Bounce these numbers against the Stratified KFold method 
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

from sklearn.model_selection import StratifiedKFold
from sklearn import metrics, cross_validation
from sklearn.cross_validation import *
from sklearn.metrics import *
from sklearn.linear_model import LogisticRegression

# %%
skf = StratifiedKFold(clean_data["nba_VORP"], n_folds = 10)
fold_count = 1

corrs = pd.DataFrame()

# Correlations with "Roster"

for train, test in skf:
    
    # Log
    print(f"\n>>> Running fold {fold_count} <<<\n")
    
    # Training & testing dfs
    train_fold = clean_data.iloc[train]
    test_fold = clean_data.iloc[test]
    
    # Best features
    corr = train_fold.corr()["nba_VORP"][train_fold.corr()["nba_VORP"] < 1]
    corrs = corrs.append(corr)
    corrs = corrs.rename(index = {"nba_VORP": f"Fold {fold_count}"})
    print(corr)
    
    # Increment fold
    fold_count += 1
# Out:
# >>> Running fold 1 <<<
#
# draft_Pk                 -0.103169
# draft_Games               0.233393
# draft_Minutes.Played      0.323814
# draft_PTS                 0.355683
# draft_TRB                 0.303760
# draft_AST                 0.341980
# draft_FG_Percentage       0.177078
# draft_TP_Percentage       0.023942
# draft_FT_Percentage       0.025080
# draft_Minutes.per.Game    0.366844
# draft_Points.per.Game     0.403005
# draft_TRB.per.game        0.332259
# draft_Assits.per.Game     0.334537
# draft_Win.Share           0.434154
# draft_WS_per_game         0.330790
# draft_BPM                 0.415751
# draft_VORP                0.550149
# draft_attend_college      0.039943
# Name: nba_VORP, dtype: float64
#
# >>> Running fold 2 <<<
#
# draft_Pk                 -0.160750
# draft_Games               0.349320
# draft_Minutes.Played      0.468490
# draft_PTS                 0.495049
# draft_TRB                 0.447635
# draft_AST                 0.488998
# draft_FG_Percentage       0.194161
# draft_TP_Percentage       0.037734
# draft_FT_Percentage       0.060925
# draft_Minutes.per.Game    0.417357
# draft_Points.per.Game     0.445375
# draft_TRB.per.game        0.371935
# draft_Assits.per.Game     0.409111
# draft_Win.Share           0.611713
# draft_WS_per_game         0.374426
# draft_BPM                 0.472634
# draft_VORP                0.698445
# draft_attend_college     -0.005082
# Name: nba_VORP, dtype: float64
#
# >>> Running fold 3 <<<
#
# draft_Pk                 -0.167251
# draft_Games               0.355587
# draft_Minutes.Played      0.460718
# draft_PTS                 0.488027
# draft_TRB                 0.430973
# draft_AST                 0.499423
# draft_FG_Percentage       0.206645
# draft_TP_Percentage       0.049293
# draft_FT_Percentage       0.077211
# draft_Minutes.per.Game    0.433081
# draft_Points.per.Game     0.461825
# draft_TRB.per.game        0.378601
# draft_Assits.per.Game     0.422034
# draft_Win.Share           0.602173
# draft_WS_per_game         0.402868
# draft_BPM                 0.524218
# draft_VORP                0.690306
# draft_attend_college     -0.033575
# Name: nba_VORP, dtype: float64
#
# >>> Running fold 4 <<<
#
# draft_Pk                 -0.175321
# draft_Games               0.340649
# draft_Minutes.Played      0.456348
# draft_PTS                 0.491018
# draft_TRB                 0.428697
# draft_AST                 0.497221
# draft_FG_Percentage       0.200008
# draft_TP_Percentage       0.062827
# draft_FT_Percentage       0.078922
# draft_Minutes.per.Game    0.444303
# draft_Points.per.Game     0.480431
# draft_TRB.per.game        0.380324
# draft_Assits.per.Game     0.433701
# draft_Win.Share           0.603000
# draft_WS_per_game         0.382234
# draft_BPM                 0.485225
# draft_VORP                0.701964
# draft_attend_college     -0.017017
# Name: nba_VORP, dtype: float64
#
# >>> Running fold 5 <<<
#
# draft_Pk                 -0.174630
# draft_Games               0.331589
# draft_Minutes.Played      0.444388
# draft_PTS                 0.477181
# draft_TRB                 0.424029
# draft_AST                 0.486913
# draft_FG_Percentage       0.201605
# draft_TP_Percentage       0.048211
# draft_FT_Percentage       0.067212
# draft_Minutes.per.Game    0.436335
# draft_Points.per.Game     0.469362
# draft_TRB.per.game        0.388403
# draft_Assits.per.Game     0.433629
# draft_Win.Share           0.593353
# draft_WS_per_game         0.390706
# draft_BPM                 0.491064
# draft_VORP                0.695431
# draft_attend_college     -0.015991
# Name: nba_VORP, dtype: float64
#
# >>> Running fold 6 <<<
#
# draft_Pk                 -0.176251
# draft_Games               0.335695
# draft_Minutes.Played      0.450289
# draft_PTS                 0.482501
# draft_TRB                 0.429578
# draft_AST                 0.484770
# draft_FG_Percentage       0.202487
# draft_TP_Percentage       0.044974
# draft_FT_Percentage       0.067904
# draft_Minutes.per.Game    0.443430
# draft_Points.per.Game     0.475875
# draft_TRB.per.game        0.392770
# draft_Assits.per.Game     0.428768
# draft_Win.Share           0.597152
# draft_WS_per_game         0.390687
# draft_BPM                 0.493908
# draft_VORP                0.693278
# draft_attend_college     -0.016161
# Name: nba_VORP, dtype: float64
#
# >>> Running fold 7 <<<
#
# draft_Pk                 -0.185652
# draft_Games               0.341760
# draft_Minutes.Played      0.457882
# draft_PTS                 0.488470
# draft_TRB                 0.431600
# draft_AST                 0.484359
# draft_FG_Percentage       0.203326
# draft_TP_Percentage       0.064302
# draft_FT_Percentage       0.070174
# draft_Minutes.per.Game    0.452039
# draft_Points.per.Game     0.480025
# draft_TRB.per.game        0.393590
# draft_Assits.per.Game     0.426449
# draft_Win.Share           0.597756
# draft_WS_per_game         0.399441
# draft_BPM                 0.499070
# draft_VORP                0.692411
# draft_attend_college     -0.003135
# Name: nba_VORP, dtype: float64
#
# >>> Running fold 8 <<<
#
# draft_Pk                 -0.174921
# draft_Games               0.334916
# draft_Minutes.Played      0.447753
# draft_PTS                 0.478999
# draft_TRB                 0.425050
# draft_AST                 0.484825
# draft_FG_Percentage       0.213759
# draft_TP_Percentage       0.056499
# draft_FT_Percentage       0.073101
# draft_Minutes.per.Game    0.446999
# draft_Points.per.Game     0.476095
# draft_TRB.per.game        0.391905
# draft_Assits.per.Game     0.437870
# draft_Win.Share           0.595694
# draft_WS_per_game         0.399695
# draft_BPM                 0.499066
# draft_VORP                0.692131
# draft_attend_college     -0.018582
# Name: nba_VORP, dtype: float64
#
# >>> Running fold 9 <<<
#
# draft_Pk                 -0.178361
# draft_Games               0.335814
# draft_Minutes.Played      0.446895
# draft_PTS                 0.478563
# draft_TRB                 0.424987
# draft_AST                 0.477479
# draft_FG_Percentage       0.216625
# draft_TP_Percentage       0.054041
# draft_FT_Percentage       0.074804
# draft_Minutes.per.Game    0.441154
# draft_Points.per.Game     0.473030
# draft_TRB.per.game        0.391575
# draft_Assits.per.Game     0.419784
# draft_Win.Share           0.592923
# draft_WS_per_game         0.426217
# draft_BPM                 0.512376
# draft_VORP                0.688238
# draft_attend_college     -0.019240
# Name: nba_VORP, dtype: float64
#
# >>> Running fold 10 <<<
#
# draft_Pk                 -0.182169
# draft_Games               0.333769
# draft_Minutes.Played      0.447083
# draft_PTS                 0.478203
# draft_TRB                 0.423111
# draft_AST                 0.477017
# draft_FG_Percentage       0.201929
# draft_TP_Percentage       0.052904
# draft_FT_Percentage       0.069594
# draft_Minutes.per.Game    0.446356
# draft_Points.per.Game     0.470764
# draft_TRB.per.game        0.393520
# draft_Assits.per.Game     0.417579
# draft_Win.Share           0.592748
# draft_WS_per_game         0.400317
# draft_BPM                 0.498520
# draft_VORP                0.689794
# draft_attend_college     -0.014142
# Name: nba_VORP, dtype: float64
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/cross_validation.py:553: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=10.
#   % (min_labels, self.n_folds)), Warning)

# %%
corrs
# Out:
#          draft_AST  draft_Assits.per.Game  draft_BPM  draft_FG_Percentage  \
# Fold 1    0.341980               0.334537   0.415751             0.177078
# Fold 2    0.488998               0.409111   0.472634             0.194161
# Fold 3    0.499423               0.422034   0.524218             0.206645
# Fold 4    0.497221               0.433701   0.485225             0.200008
# Fold 5    0.486913               0.433629   0.491064             0.201605
# Fold 6    0.484770               0.428768   0.493908             0.202487
# Fold 7    0.484359               0.426449   0.499070             0.203326
# Fold 8    0.484825               0.437870   0.499066             0.213759
# Fold 9    0.477479               0.419784   0.512376             0.216625
# Fold 10   0.477017               0.417579   0.498520             0.201929
#
#          draft_FT_Percentage  draft_Games  draft_Minutes.Played  \
# Fold 1              0.025080     0.233393              0.323814
# Fold 2              0.060925     0.349320              0.468490
# Fold 3              0.077211     0.355587              0.460718
# Fold 4              0.078922     0.340649              0.456348
# Fold 5              0.067212     0.331589              0.444388
# Fold 6              0.067904     0.335695              0.450289
# Fold 7              0.070174     0.341760              0.457882
# Fold 8              0.073101     0.334916              0.447753
# Fold 9              0.074804     0.335814              0.446895
# Fold 10             0.069594     0.333769              0.447083
#
#          draft_Minutes.per.Game  draft_PTS  draft_Pk  draft_Points.per.Game  \
# Fold 1                 0.366844   0.355683 -0.103169               0.403005
# Fold 2                 0.417357   0.495049 -0.160750               0.445375
# Fold 3                 0.433081   0.488027 -0.167251               0.461825
# Fold 4                 0.444303   0.491018 -0.175321               0.480431
# Fold 5                 0.436335   0.477181 -0.174630               0.469362
# Fold 6                 0.443430   0.482501 -0.176251               0.475875
# Fold 7                 0.452039   0.488470 -0.185652               0.480025
# Fold 8                 0.446999   0.478999 -0.174921               0.476095
# Fold 9                 0.441154   0.478563 -0.178361               0.473030
# Fold 10                0.446356   0.478203 -0.182169               0.470764
#
#          draft_TP_Percentage  draft_TRB  draft_TRB.per.game  draft_VORP  \
# Fold 1              0.023942   0.303760            0.332259    0.550149
# Fold 2              0.037734   0.447635            0.371935    0.698445
# Fold 3              0.049293   0.430973            0.378601    0.690306
# Fold 4              0.062827   0.428697            0.380324    0.701964
# Fold 5              0.048211   0.424029            0.388403    0.695431
# Fold 6              0.044974   0.429578            0.392770    0.693278
# Fold 7              0.064302   0.431600            0.393590    0.692411
# Fold 8              0.056499   0.425050            0.391905    0.692131
# Fold 9              0.054041   0.424987            0.391575    0.688238
# Fold 10             0.052904   0.423111            0.393520    0.689794
#
#          draft_WS_per_game  draft_Win.Share  draft_attend_college
# Fold 1            0.330790         0.434154              0.039943
# Fold 2            0.374426         0.611713             -0.005082
# Fold 3            0.402868         0.602173             -0.033575
# Fold 4            0.382234         0.603000             -0.017017
# Fold 5            0.390706         0.593353             -0.015991
# Fold 6            0.390687         0.597152             -0.016161
# Fold 7            0.399441         0.597756             -0.003135
# Fold 8            0.399695         0.595694             -0.018582
# Fold 9            0.426217         0.592923             -0.019240
# Fold 10           0.400317         0.592748             -0.014142

# %%
avg_corrs = pd.DataFrame(corrs.mean())
avg_corrs.columns = ["Avg corr"]
avg_corrs["Avg corr (Abs)"] = avg_corrs["Avg corr"].abs()
avg_corrs.sort_values(["Avg corr (Abs)"], ascending = False)
# Out:
#                         Avg corr  Avg corr (Abs)
# draft_VORP              0.679215        0.679215
# draft_Win.Share         0.582067        0.582067
# draft_BPM               0.489183        0.489183
# draft_AST               0.472299        0.472299
# draft_PTS               0.471369        0.471369
# draft_Points.per.Game   0.463579        0.463579
# draft_Minutes.Played    0.440366        0.440366
# draft_Minutes.per.Game  0.432790        0.432790
# draft_TRB               0.416942        0.416942
# draft_Assits.per.Game   0.416346        0.416346
# draft_WS_per_game       0.389738        0.389738
# draft_TRB.per.game      0.381488        0.381488
# draft_Games             0.329249        0.329249
# draft_FG_Percentage     0.201762        0.201762
# draft_Pk               -0.167847        0.167847
# draft_FT_Percentage     0.066493        0.066493
# draft_TP_Percentage     0.049473        0.049473
# draft_attend_college   -0.010298        0.010298

# %%
#virtually the same - I'll go with the heatmap for visualization purposes 
#because it also shows correlation among independent variables

# %%
sel_var = avg_corrs[avg_corrs["Avg corr (Abs)"] > .3].index.values.tolist()
sel_var
# Out:
# ['draft_AST',
#  'draft_Assits.per.Game',
#  'draft_BPM',
#  'draft_Games',
#  'draft_Minutes.Played',
#  'draft_Minutes.per.Game',
#  'draft_PTS',
#  'draft_Points.per.Game',
#  'draft_TRB',
#  'draft_TRB.per.game',
#  'draft_VORP',
#  'draft_WS_per_game',
#  'draft_Win.Share']

# %%
sns.regplot(clean_data1.nba_VORP, clean_data1['draft_BPM'])

plt.show()

# %%
y2 = clean_data.nba_VORP.values
X2 = clean_data[sel_var]
print("Shape:", X2.shape, y2.shape)
# Out:
# Shape: (648, 13) (648,)

# %%
from sklearn.linear_model import LinearRegression
reg2 = LinearRegression()

# %%
from sklearn.cross_validation import train_test_split

X2_train , X2_test , y2_train , y2_test = train_test_split(X2 ,y2, test_size = 0.10,random_state =2)

# %%
reg2.fit(X2_train, y2_train)
reg2.score(X2_test, y2_test)
# Out:
# 0.52195600211583693

# %%
#try to boost the score some
from sklearn import ensemble
clf2 = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
          learning_rate = 0.1, loss = 'ls')

# %%
clf2.fit(X2_train, y2_train)
clf2.score(X2_test, y2_test)
# Out:
# 0.64851326447393087

# %%
#Let's try the values with low p-values
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
model = sm.OLS(y2_train,X2_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.529
# Model:                            OLS   Adj. R-squared:                  0.518
# Method:                 Least Squares   F-statistic:                     49.22
# Date:                Mon, 23 Apr 2018   Prob (F-statistic):           2.48e-84
# Time:                        19:16:26   Log-Likelihood:                -379.37
# No. Observations:                 583   AIC:                             784.7
# Df Residuals:                     570   BIC:                             841.5
# Df Model:                          13
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# draft_AST                 -0.0001   9.46e-05     -1.402      0.161      -0.000    5.32e-05
# draft_Assits.per.Game      0.0692      0.049      1.417      0.157      -0.027       0.165
# draft_BPM                  0.0254      0.009      2.974      0.003       0.009       0.042
# draft_Games               -0.0004      0.000     -1.181      0.238      -0.001       0.000
# draft_Minutes.Played    8.763e-05    2.8e-05      3.135      0.002    3.27e-05       0.000
# draft_Minutes.per.Game    -0.0408      0.012     -3.317      0.001      -0.065      -0.017
# draft_PTS                 -0.0002   4.25e-05     -3.838      0.000      -0.000   -7.96e-05
# draft_Points.per.Game      0.0664      0.023      2.946      0.003       0.022       0.111
# draft_TRB                 -0.0002   6.43e-05     -2.977      0.003      -0.000   -6.52e-05
# draft_TRB.per.game         0.0896      0.031      2.905      0.004       0.029       0.150
# draft_VORP                 0.0695      0.009      8.143      0.000       0.053       0.086
# draft_WS_per_game         -0.2785      0.548     -0.509      0.611      -1.354       0.797
# draft_Win.Share            0.0021      0.006      0.375      0.708      -0.009       0.013
# ==============================================================================
# Omnibus:                       44.239   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              123.186
# Skew:                           0.348   Prob(JB):                     1.78e-27
# Kurtosis:                       5.142   Cond. No.                     3.37e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.37e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#variables with low p-values = less than .05
significant_data = ["draft_Minutes.Played", "draft_PTS", "draft_TRB", "draft_Minutes.per.Game",
                    "draft_Points.per.Game","draft_TRB.per.game","draft_VORP"
                   ]

# %%
y3 = clean_data.nba_VORP.values
X3 = clean_data[significant_data]

# %%
from sklearn.linear_model import LinearRegression
reg3 = LinearRegression()

# %%
from sklearn.cross_validation import train_test_split

X3_train , X3_test , y3_train , y3_test = train_test_split(X3 ,y3, test_size = 0.10,random_state =2)

# %%
reg3.fit(X3_train, y3_train)
reg3.score(X3_test, y3_test)
# Out:
# 0.46053498200917564

# %%
#try to boost the score some
from sklearn import ensemble
clf3 = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
          learning_rate = 0.1, loss = 'ls')

# %%
clf3.fit(X3_train, y3_train)
clf3.score(X3_test, y3_test)
# Out:
# 0.59375374354185273

# %%
#Print coefficients and intercept for important indep. variables
print("Coefficients:", reg2.coef_)
print("Intercept:", reg2.intercept_)
# Out:
# Coefficients: [ -1.25195841e-04   6.53719788e-02   4.12394316e-02  -5.70813180e-04
#    9.88836711e-05  -4.86051526e-02  -1.77246301e-04   7.58504550e-02
#   -1.91265187e-04   8.96664888e-02   6.51501577e-02  -7.77567234e-01
#    3.70602491e-03]
# Intercept: 0.153526815449

# %%
#Show which variables have greater weight in linear regression model
model_coef_df = pd.DataFrame(reg2.coef_, columns=["model_coef"])
model_coef_df.index = X2.columns

# %%
model_coefs = pd.DataFrame({'variable': X2.columns,
                           'coefficient': reg2.coef_,
                           'abs_coef': np.abs(reg2.coef_)})
model_coefs.sort_values('coefficient', inplace=True, ascending=False)
model_coefs
# Out:
#     abs_coef  coefficient                variable
# 9   0.089666     0.089666      draft_TRB.per.game
# 7   0.075850     0.075850   draft_Points.per.Game
# 1   0.065372     0.065372   draft_Assits.per.Game
# 10  0.065150     0.065150              draft_VORP
# 2   0.041239     0.041239               draft_BPM
# 12  0.003706     0.003706         draft_Win.Share
# 4   0.000099     0.000099    draft_Minutes.Played
# 0   0.000125    -0.000125               draft_AST
# 6   0.000177    -0.000177               draft_PTS
# 8   0.000191    -0.000191               draft_TRB
# 3   0.000571    -0.000571             draft_Games
# 5   0.048605    -0.048605  draft_Minutes.per.Game
# 11  0.777567    -0.777567       draft_WS_per_game

# %%
#Predicted vs. Actual
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# %%
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics
scores = cross_val_score(reg2, X2_train, y2_train, cv =10)
scores
# Out:
# array([ 0.13158133,  0.45064216,  0.25221308,  0.47129474,  0.49423954,
#         0.42604261,  0.60918037,  0.00819449,  0.63271239,  0.58044822])

# %%
predictions = cross_val_predict(reg2, X2_train, y2_train, cv =6)
sns.regplot(y2_train, predictions)

# %%
accuracy = metrics.r2_score(y2_train, predictions)
print("Cross-Predicted Accuracy:", accuracy)
# Out:
# Cross-Predicted Accuracy: 0.460817550128

# %%
#FINALLY NBA VORP PREDICTIONS
predicted_vorp = pd.DataFrame(clf2.predict(X2))
predicted_vorp.columns = ['Predicted_VORP']
pred_feat = clean_data1[sel_var]
player = clean_data1['draft_Player']
actual_vorp = clean_data['nba_VORP']
vorp_diff = actual_vorp - predicted_vorp
prediction_df = pd.concat([player, pred_feat, actual_vorp, predicted_vorp], axis=1)
prediction_df["Predicted_VORP"] = prediction_df['Predicted_VORP'].round(1)
prediction_df["VORP_diff"] = (prediction_df["nba_VORP"]-prediction_df["Predicted_VORP"])
prediction_df["Abs_diff"] = np.abs(prediction_df['VORP_diff'])
prediction_df.head()
# Out:
#       draft_Player  draft_AST  draft_Assits.per.Game  draft_BPM  draft_Games  \
# 0   Stromile Swift        275                    0.5       -1.9          547
# 1  Jamaal Magloire        386                    0.6       -2.9          680
# 2    Erick Barkley         40                    1.5       -3.8           27
# 3  Jake Tsakalidis        101                    0.3       -3.1          315
# 4   Joel Przybilla        256                    0.4       -0.9          592
#
#    draft_Minutes.Played  draft_Minutes.per.Game  draft_PTS  \
# 0                 10804                    19.8       4582
# 1                 14621                    21.5       4917
# 2                   266                     9.9         77
# 3                  5005                    15.9       1497
# 4                 11733                    19.8       2293
#
#    draft_Points.per.Game  draft_TRB  draft_TRB.per.game  draft_VORP  \
# 0                    8.4       2535                 4.6         0.2
# 1                    7.2       4408                 6.5        -3.3
# 2                    2.9         21                 0.8        -0.1
# 3                    4.8       1238                 3.9        -1.3
# 4                    3.9       3665                 6.2         3.3
#
#    draft_WS_per_game  draft_Win.Share  nba_VORP  Predicted_VORP  VORP_diff  \
# 0              0.095             21.3       0.2             0.2        0.0
# 1              0.091             27.7      -0.2            -0.5        0.3
# 2              0.027              0.2       0.0            -0.0        0.0
# 3              0.095              9.9      -0.4            -0.4        0.0
# 4              0.094             23.0      -0.1            -0.1        0.0
#
#    Abs_diff
# 0       0.0
# 1       0.3
# 2       0.0
# 3       0.0
# 4       0.0

# %%
prediction_df.sort_values('Abs_diff', ascending=True)
# Out:
#           draft_Player  draft_AST  draft_Assits.per.Game  draft_BPM  \
# 0       Stromile Swift        275                    0.5       -1.9
# 419    Marcus Thornton        636                    1.4       -0.7
# 420       DeJuan Blair        349                    0.8        0.4
# 421        Jeff Teague       2671                    5.2       -0.2
# 422   Gerald Henderson        897                    1.9       -2.1
# 423      Derrick Brown        119                    0.7       -1.6
# 424       James Harden       2620                    4.9        5.3
# 425  Rodrigue Beaubois        374                    2.1       -0.1
# 426         Earl Clark        134                    0.5       -3.6
# 427     Taylor Griffin          1                    0.1       -7.3
# 428           Ed Davis        372                    0.9        1.4
# 429       Xavier Henry        120                    0.6       -5.1
# 430    Dominique Jones        144                    1.8       -3.6
# 431    Greivis Vasquez       1930                    4.8       -1.5
# 432      Avery Bradley        581                    1.6       -1.6
# 433     Luke Harangody         36                    0.5       -3.3
# 418      Toney Douglas        833                    2.3       -0.6
# 434  Patrick Patterson        502                    1.2        0.7
# 416         A.J. Price        567                    2.2       -2.4
# 414  Terrence Williams        364                    2.4       -3.8
# 399    Jermaine Taylor         48                    0.7       -4.6
# 400      James Johnson        590                    1.5        0.8
# 401         Taj Gibson        504                    1.0        0.1
# 402       Tyreke Evans       2293                    5.3        0.9
# 403        Omri Casspi        548                    1.2       -1.4
# 404    Darren Collison       2404                    4.9       -0.1
# 405        Austin Daye        212                    0.7       -2.6
# 406     DaJuan Summers         29                    0.3       -6.4
# 407      Jonas Jerebko        316                    0.8       -0.8
# 408     Chase Budinger        473                    1.2       -1.4
# ..                 ...        ...                    ...        ...
# 130      Dahntay Jones        528                    0.8       -3.6
# 322     Rodney Stuckey       2249                    3.7       -1.2
# 1      Jamaal Magloire        386                    0.6       -2.9
# 157       Willie Green       1018                    1.4       -3.6
# 198     David Harrison         47                    0.2       -3.4
# 68         Tony Parker       6349                    5.9        1.1
# 417      Stephen Curry       3393                    6.9        6.2
# 465     Derrick Favors        454                    1.1        0.9
# 176       Al Jefferson       1260                    1.5        0.4
# 579       Mike Muscala         66                    0.6       -0.6
# 192   Anderson Varejao        724                    1.2        1.5
# 613       Clint Capela         49                    0.6        0.0
# 580       Solomon Hill        253                    1.5       -0.4
# 109      Carlos Boozer       1928                    2.2        1.2
# 80           Pau Gasol       3485                    3.3        3.5
# 37       Kenyon Martin       1439                    1.9        0.7
# 212    Marvin Williams       1019                    1.3       -0.5
# 55       Jason Collins        626                    0.9       -2.0
# 183       Kevin Martin       1352                    1.9        0.1
# 182       Devin Harris       3459                    4.4        0.6
# 596      C.J. McCollum        432                    2.4       -0.3
# 511        Cory Joseph        639                    2.3       -0.4
# 396      Byron Mullens        153                    0.8       -4.6
# 89   Amar'e Stoudemire       1050                    1.2        0.5
# 18        Marcus Fizer        352                    1.2       -4.7
# 141       LeBron James       6815                    6.9        9.2
# 377       Goran Dragic       2692                    4.7        1.2
# 451     Gordon Hayward       1510                    3.4        1.6
# 165         J.R. Smith       1850                    2.2        0.5
# 120       Caron Butler       2007                    2.3        0.2
#
#      draft_Games  draft_Minutes.Played  draft_Minutes.per.Game  draft_PTS  \
# 0            547                 10804                    19.8       4582
# 419          450                 10724                    23.8       5531
# 420          424                  7054                    16.6       2865
# 421          518                 13518                    26.1       6291
# 422          463                 12187                    26.3       5325
# 423          171                  2554                    14.9        895
# 424          534                 17741                    33.2      11262
# 425          182                  2896                    15.9       1286
# 426          261                  3630                    13.9       1138
# 427            8                    32                     4.0         10
# 428          435                  9247                    21.3       3078
# 429          185                  2905                    15.7       1050
# 430           80                   741                     9.3        246
# 431          398                  9481                    23.8       3584
# 432          358                  9784                    27.3       4114
# 433           70                   871                    12.4        253
# 418          370                  7117                    19.2       2892
# 434          412                  9835                    23.9       3301
# 416          261                  3929                    15.1       1523
# 414          153                  2922                    19.1       1085
# 399           65                   786                    12.1        351
# 400          398                  7270                    18.3       2594
# 401          507                 12668                    25.0       4641
# 402          433                 14445                    33.4       7220
# 403          463                 10056                    21.7       3930
# 404          495                 14572                    29.4       6249
# 405          293                  4132                    14.1       1522
# 406           83                   820                     9.9        278
# 407          410                  7739                    18.9       2732
# 408          407                  7998                    19.7       3198
# ..           ...                   ...                     ...        ...
# 130          623                  9787                    15.7       3344
# 322          612                 17194                    28.1       7904
# 1            680                 14621                    21.5       4917
# 157          731                 14783                    20.2       6059
# 198          189                  2686                    14.2        949
# 68          1080                 34618                    32.1      17884
# 417          495                 17259                    34.9      11089
# 465          429                 11162                    26.0       5003
# 176          813                 24884                    30.6      13556
# 579          120                  1282                    10.7        468
# 192          613                 14959                    24.4       4543
# 613           89                  1561                    17.5        574
# 580          169                  3473                    20.6       1022
# 109          861                 26901                    31.2      13976
# 80          1055                 37202                    35.3      19209
# 37           757                 23134                    30.6       9325
# 212          785                 22596                    28.8       8273
# 55           735                 14974                    20.4       2621
# 183          714                 21559                    30.2      12396
# 182          781                 20465                    26.2       9137
# 596          180                  4229                    23.5       2291
# 511          284                  5080                    17.9       1739
# 396          189                  3446                    18.2       1398
# 89           846                 26254                    31.0      15994
# 18           289                  6032                    20.9       2782
# 141          987                 38478                    39.0      26833
# 377          574                 15408                    26.8       7148
# 451          443                 13648                    30.8       6476
# 165          839                 22543                    26.9      11044
# 120          881                 28333                    32.2      12430
#
#      draft_Points.per.Game  draft_TRB  draft_TRB.per.game  draft_VORP  \
# 0                      8.4       2535                 4.6         0.2
# 419                   12.3       1272                 2.8         3.6
# 420                    6.8       2153                 5.1         4.2
# 421                   12.1       1114                 2.2         6.2
# 422                   11.5       1531                 3.3        -0.4
# 423                    5.2        413                 2.4         0.2
# 424                   21.1       2434                 4.6        32.6
# 425                    7.1        338                 1.9         1.4
# 426                    4.4        778                 3.0        -1.5
# 427                    1.3          2                 0.3         0.0
# 428                    7.1       2819                 6.5         7.9
# 429                    5.7        351                 1.9        -2.3
# 430                    3.1        114                 1.4        -0.3
# 431                    9.0       1019                 2.6         1.2
# 432                   11.5        930                 2.6         1.1
# 433                    3.6        196                 2.8        -0.3
# 418                    7.8        814                 2.2         2.5
# 434                    8.0       1940                 4.7         6.7
# 416                    5.8        377                 1.4        -0.4
# 414                    7.1        545                 3.6        -1.4
# 399                    5.4        108                 1.7        -0.5
# 400                    6.5       1256                 3.2         5.2
# 401                    9.2       3204                 6.3         6.6
# 402                   16.7       2117                 4.9        10.7
# 403                    8.5       1928                 4.2         1.6
# 404                   12.6       1323                 2.7         6.9
# 405                    5.2        764                 2.6        -0.6
# 406                    3.3         82                 1.0        -0.9
# 407                    6.7       1716                 4.2         2.4
# 408                    7.9       1240                 3.0         1.2
# ..                     ...        ...                 ...         ...
# 130                    5.4       1080                 1.7        -4.1
# 322                   12.9       1828                 3.0         3.4
# 1                      7.2       4408                 6.5        -3.3
# 157                    8.3       1303                 1.8        -5.9
# 198                    5.0        549                 2.9        -1.0
# 68                    16.6       3105                 2.9        27.5
# 417                   22.4       2149                 4.3        35.6
# 465                   11.7       3130                 7.3         8.1
# 176                   16.7       7269                 8.9        15.1
# 579                    3.9        288                 2.4         0.5
# 192                    7.4       4484                 7.3        13.3
# 613                    6.4        530                 6.0         0.8
# 580                    6.0        521                 3.1         1.4
# 109                   16.2       8192                 9.5        22.1
# 80                    18.2      10048                 9.5        51.8
# 37                    12.3       5159                 6.8        15.5
# 212                   10.5       4086                 5.2         8.6
# 55                     3.6       2706                 3.7         0.2
# 183                   17.4       2278                 3.2        11.3
# 182                   11.7       1785                 2.3        13.3
# 596                   12.7        398                 2.2         1.8
# 511                    6.1        586                 2.1         2.1
# 396                    7.4        790                 4.2        -2.3
# 89                    18.9       6632                 7.8        16.8
# 18                     9.6       1340                 4.6        -4.1
# 141                   27.2       7067                 7.2       108.6
# 377                   12.5       1618                 2.8        12.4
# 451                   14.6       1755                 4.0        12.4
# 165                   13.2       2702                 3.2        14.3
# 120                   14.1       4387                 5.0        15.9
#
#      draft_WS_per_game  draft_Win.Share  nba_VORP  Predicted_VORP  VORP_diff  \
# 0                0.095             21.3       0.2             0.2        0.0
# 419              0.087             19.5       0.8             0.8        0.0
# 420              0.129             19.0       1.0             1.0        0.0
# 421              0.118             33.1      -0.4            -0.4        0.0
# 422              0.064             16.2      -0.2            -0.2        0.0
# 423              0.085              4.5       0.0             0.0        0.0
# 424              0.206             76.3       1.3             1.3        0.0
# 425              0.079              4.8       0.6             0.6        0.0
# 426              0.038              2.9      -0.5            -0.5        0.0
# 427             -0.039              0.0       0.0            -0.0        0.0
# 428              0.150             28.8       0.9             0.9        0.0
# 429              0.013              0.8      -0.5            -0.5        0.0
# 430              0.017              0.3       0.0            -0.0        0.0
# 431              0.064             12.6      -0.6            -0.6        0.0
# 432              0.056             11.3      -0.3            -0.3        0.0
# 433              0.048              0.9      -0.1            -0.1        0.0
# 418              0.078             11.6       0.3             0.3        0.0
# 434              0.106             21.7       0.5             0.5        0.0
# 416              0.058              4.7       0.0            -0.0        0.0
# 414             -0.004             -0.2      -0.8            -0.8        0.0
# 399              0.014              0.2      -0.3            -0.3        0.0
# 400              0.079             11.9       0.0             0.0        0.0
# 401              0.127             33.6       0.8             0.8        0.0
# 402              0.077             23.1       2.5             2.5        0.0
# 403              0.074             15.6      -0.1            -0.1        0.0
# 404              0.104             31.6       0.2             0.2        0.0
# 405              0.053              4.5      -0.2            -0.2        0.0
# 406             -0.008             -0.1      -0.4            -0.4        0.0
# 407              0.105             17.0       1.0             1.0        0.0
# 408              0.083             13.9       0.3             0.3        0.0
# ..                 ...              ...       ...             ...        ...
# 130              0.048              9.9      -0.2            -0.5        0.3
# 322              0.080             28.7       0.3             0.0        0.3
# 1                0.091             27.7      -0.2            -0.5        0.3
# 157              0.042             12.9      -0.8            -1.1        0.3
# 198              0.057              3.2       0.1            -0.2        0.3
# 68               0.147            105.9       0.9             0.6        0.3
# 417              0.199             71.6       2.2             2.6       -0.4
# 465              0.133             30.8       0.0             0.4       -0.4
# 176              0.129             67.1      -0.2             0.2       -0.4
# 579              0.137              3.7      -0.2             0.2       -0.4
# 192              0.148             46.2       0.7             0.2        0.5
# 613              0.137              4.5      -0.1             0.4       -0.5
# 580              0.084              6.0       0.0             0.5       -0.5
# 109              0.143             80.3       1.1             0.6        0.5
# 80               0.168            130.6       3.2             2.6        0.6
# 37               0.100             48.0       0.8             0.2        0.6
# 212              0.104             48.9      -0.8            -0.2       -0.6
# 55               0.064             20.1       0.4            -0.2        0.6
# 183              0.137             61.3      -0.3             0.4       -0.7
# 182              0.114             48.7       0.9             0.2        0.7
# 596              0.091              8.0      -0.3             0.4       -0.7
# 511              0.111             11.8      -0.2             0.5       -0.7
# 396              0.008              0.6      -0.1            -0.8        0.7
# 89               0.169             92.5       0.6            -0.2        0.8
# 18               0.022              2.7      -2.1            -1.2       -0.9
# 141              0.240            192.5       3.1             4.1       -1.0
# 377              0.114             36.6      -0.2             0.8       -1.0
# 451              0.115             32.6      -0.2             0.8       -1.0
# 165              0.094             44.3      -0.7             0.5       -1.2
# 120              0.086             50.9       2.7             0.3        2.4
#
#      Abs_diff
# 0         0.0
# 419       0.0
# 420       0.0
# 421       0.0
# 422       0.0
# 423       0.0
# 424       0.0
# 425       0.0
# 426       0.0
# 427       0.0
# 428       0.0
# 429       0.0
# 430       0.0
# 431       0.0
# 432       0.0
# 433       0.0
# 418       0.0
# 434       0.0
# 416       0.0
# 414       0.0
# 399       0.0
# 400       0.0
# 401       0.0
# 402       0.0
# 403       0.0
# 404       0.0
# 405       0.0
# 406       0.0
# 407       0.0
# 408       0.0
# ..        ...
# 130       0.3
# 322       0.3
# 1         0.3
# 157       0.3
# 198       0.3
# 68        0.3
# 417       0.4
# 465       0.4
# 176       0.4
# 579       0.4
# 192       0.5
# 613       0.5
# 580       0.5
# 109       0.5
# 80        0.6
# 37        0.6
# 212       0.6
# 55        0.6
# 183       0.7
# 182       0.7
# 596       0.7
# 511       0.7
# 396       0.7
# 89        0.8
# 18        0.9
# 141       1.0
# 377       1.0
# 451       1.0
# 165       1.2
# 120       2.4
#
# [648 rows x 18 columns]

# %%
#need to round my data to one decimal point

# %%
prediction_df.to_csv("VORP_2000to2015_Predictions.csv")

# %%
import pickle
pickle.dump(reg2, open("VORPRegression_Model.pkl", "wb"))

# %%
#Test on New Data
new_draft = pd.read_csv("draft16_nba17_vorp.csv")
new_draft
# Out:
#     draft_Pk draft_Team           draft_Player  Roster  \
# 0          1        PHI            Ben Simmons       1
# 1          2        LAL         Brandon Ingram       1
# 2          3        BOS           Jaylen Brown       1
# 3          4        PHO          Dragan Bender       1
# 4          5        MIN              Kris Dunn       1
# 5          6        NOP            Buddy Hield       1
# 6          7        DEN           Jamal Murray       1
# 7          8        SAC        Marquese Chriss       1
# 8          9        TOR           Jakob Poeltl       1
# 9         10        MIL             Thon Maker       1
# 10        11        ORL       Domantas Sabonis       1
# 11        12        UTA  Taurean Waller-Prince       1
# 12        13        PHO   Georgios Papagiannis       1
# 13        14        CHI       Denzel Valentine       1
# 14        15        DEN       Juan Hernangomez       0
# 15        16        BOS     Guerschon Yabusele       1
# 16        17        MEM           Wade Baldwin       0
# 17        18        DET         Henry Ellenson       1
# 18        19        DEN          Malik Beasley       1
# 19        20        IND           Caris LeVert       1
# 20        21        ATL         DeAndre Bembry       0
# 21        22        CHO     Malachi Richardson       1
# 22        23        BOS             Ante Zizic       1
# 23        24        PHI         Timothe Luwawu       0
# 24        25        LAC          Brice Johnson       1
# 25        26        PHI         Furkan Korkmaz       1
# 26        27        TOR          Pascal Siakam       1
# 27        28        PHO        Skal Labissiere       1
# 28        29        SAS        Dejounte Murray       1
# 29        30        GSW           Damian Jones       1
# 30        31        BOS          Deyonta Davis       1
# 31        32        LAL            Ivica Zubac       1
# 32        33        LAC          Cheick Diallo       1
# 33        34        PHO             Tyler Ulis       1
# 34        35        BOS           Rade Zagorac       0
# 35        36        MIL        Malcolm Brogdon       1
# 36        37        HOU         Chinanu Onuaku       1
# 37        38        MIL          Patrick McCaw       1
# 38        39        NOP        David Michineau       0
# 39        40        NOP          Diamond Stone       0
# 40        41        ORL      Stephen Zimmerman       0
# 41        42        UTA       Isaiah Whitehead       1
# 42        43        HOU                Zhou Qi       1
# 43        44        ATL        Isaia Cordinier       0
# 44        45        BOS      Demetrius Jackson       1
# 45        46        DAL           A.J. Hammons       0
# 46        47        ORL            Jake Layman       1
# 47        48        CHI            Paul Zipser       1
# 48        49        DET        Michael Gbinije       0
# 49        50        IND          Georges Niang       1
# 50        51        BOS             Ben Bentil       0
# 51        52        UTA          Joel Bolomboy       1
# 52        53        DEN          Petr Cornelie       0
# 53        54        ATL             Kay Felder       1
# 54        55        BRK           Marcus Paige       1
# 55        56        DEN        Daniel Hamilton       1
# 56        57        MEM            Wang Zhelin       0
# 57        58        BOS            Abdel Nader       1
# 58        59        SAC         Isaiah Cousins       0
# 59        60        UTA         Tyrone Wallace       1
#
#                       draft_College  draft_attend_college  draft_Yrs  \
# 0        Louisiana State University                     1        1.0
# 1                   Duke University                     1        2.0
# 2          University of California                     1        2.0
# 3                               NaN                     0        2.0
# 4                Providence College                     1        2.0
# 5            University of Oklahoma                     1        2.0
# 6            University of Kentucky                     1        2.0
# 7          University of Washington                     1        2.0
# 8                University of Utah                     1        2.0
# 9                               NaN                     0        2.0
# 10               Gonzaga University                     1        2.0
# 11                Baylor University                     1        2.0
# 12                              NaN                     0        2.0
# 13        Michigan State University                     1        2.0
# 14                              NaN                     0        2.0
# 15                              NaN                     0        1.0
# 16            Vanderbilt University                     1        2.0
# 17             Marquette University                     1        2.0
# 18         Florida State University                     1        2.0
# 19           University of Michigan                     1        2.0
# 20        Saint Joseph's University                     1        2.0
# 21              Syracuse University                     1        2.0
# 22                              NaN                     0        1.0
# 23                              NaN                     0        2.0
# 24     University of North Carolina                     1        2.0
# 25                              NaN                     0        1.0
# 26      New Mexico State University                     1        2.0
# 27           University of Kentucky                     1        2.0
# 28         University of Washington                     1        2.0
# 29            Vanderbilt University                     1        2.0
# 30        Michigan State University                     1        2.0
# 31                              NaN                     0        2.0
# 32             University of Kansas                     1        2.0
# 33           University of Kentucky                     1        2.0
# 34                              NaN                     0        NaN
# 35           University of Virginia                     1        2.0
# 36         University of Louisville                     1        2.0
# 37  University of Nevada, Las Vegas                     1        2.0
# 38                              NaN                     0        NaN
# 39           University of Maryland                     1        1.0
# 40  University of Nevada, Las Vegas                     1        1.0
# 41            Seton Hall University                     1        2.0
# 42                              NaN                     0        1.0
# 43                              NaN                     0        NaN
# 44         University of Notre Dame                     1        2.0
# 45                Purdue University                     1        1.0
# 46           University of Maryland                     1        2.0
# 47                              NaN                     0        2.0
# 48              Syracuse University                     1        1.0
# 49            Iowa State University                     1        2.0
# 50               Providence College                     1        1.0
# 51           Weber State University                     1        2.0
# 52                              NaN                     0        NaN
# 53               Oakland University                     1        2.0
# 54     University of North Carolina                     1        1.0
# 55        University of Connecticut                     1        1.0
# 56                              NaN                     0        NaN
# 57            Iowa State University                     1        1.0
# 58           University of Oklahoma                     1        NaN
# 59         University of California                     1        1.0
#
#     draft_Games  draft_Minutes.Played  draft_PTS    ...     \
# 0          81.0                2732.0     1279.0    ...
# 1         138.0                4254.0     1689.0    ...
# 2         148.0                3493.0     1532.0    ...
# 3         125.0                2643.0      677.0    ...
# 4         130.0                2858.0      992.0    ...
# 5         162.0                3912.0     1945.0    ...
# 6         163.0                4329.0     2163.0    ...
# 7         154.0                3270.0     1309.0    ...
# 8         136.0                2150.0      732.0    ...
# 9         131.0                1800.0      582.0    ...
# 10        155.0                3442.0     1340.0    ...
# 11        141.0                3445.0     1493.0    ...
# 12         39.0                 477.0      160.0    ...
# 13        134.0                3071.0     1074.0    ...
# 14         87.0                1119.0      387.0    ...
# 15         33.0                 235.0       79.0    ...
# 16         40.0                 485.0      144.0    ...
# 17         57.0                 475.0      211.0    ...
# 18         84.0                 748.0      279.0    ...
# 19        128.0                3101.0     1326.0    ...
# 20         64.0                 826.0      237.0    ...
# 21         48.0                 522.0      168.0    ...
# 22         32.0                 214.0      119.0    ...
# 23        121.0                1997.0      744.0    ...
# 24         21.0                 107.0       47.0    ...
# 25         14.0                  80.0       23.0    ...
# 26        136.0                2538.0      818.0    ...
# 27         93.0                1852.0      812.0    ...
# 28        119.0                2065.0      784.0    ...
# 29         25.0                 174.0       44.0    ...
# 30         98.0                1181.0      418.0    ...
# 31         81.0                1019.0      445.0    ...
# 32         69.0                 780.0      341.0    ...
# 33        132.0                2781.0      998.0    ...
# 34          NaN                   NaN        NaN    ...
# 35        123.0                3418.0     1392.0    ...
# 36          6.0                  74.0       18.0    ...
# 37        128.0                2035.0      511.0    ...
# 38          NaN                   NaN        NaN    ...
# 39          7.0                  24.0       10.0    ...
# 40         19.0                 108.0       23.0    ...
# 41         89.0                1823.0      643.0    ...
# 42         18.0                 124.0       22.0    ...
# 43          NaN                   NaN        NaN    ...
# 44         20.0                  97.0       26.0    ...
# 45         22.0                 163.0       48.0    ...
# 46         70.0                 409.0      112.0    ...
# 47         98.0                1667.0      458.0    ...
# 48          9.0                  32.0        4.0    ...
# 49         32.0                 125.0       30.0    ...
# 50          3.0                  10.0        0.0    ...
# 51         18.0                  91.0       31.0    ...
# 52          NaN                   NaN        NaN    ...
# 53         58.0                 526.0      223.0    ...
# 54          5.0                  28.0       12.0    ...
# 55          6.0                  28.0       12.0    ...
# 56          NaN                   NaN        NaN    ...
# 57         48.0                 522.0      146.0    ...
# 58          NaN                   NaN        NaN    ...
# 59         30.0                 851.0      291.0    ...
#
#     draft_FT_Percentage  draft_Minutes.per.Game  draft_Points.per.Game  \
# 0                 0.560                    33.7                   15.8
# 1                 0.655                    30.8                   12.2
# 2                 0.658                    23.6                   10.4
# 3                 0.694                    21.1                    5.4
# 4                 0.690                    22.0                    7.6
# 5                 0.860                    24.1                   12.0
# 6                 0.898                    26.6                   13.3
# 7                 0.617                    21.2                    8.5
# 8                 0.576                    15.8                    5.4
# 9                 0.683                    13.7                    4.4
# 10                0.729                    22.2                    8.6
# 11                0.825                    24.4                   10.6
# 12                0.857                    12.2                    4.1
# 13                0.754                    22.9                    8.0
# 14                0.761                    12.9                    4.4
# 15                0.682                     7.1                    2.4
# 16                0.787                    12.1                    3.6
# 17                0.784                     8.3                    3.7
# 18                0.698                     8.9                    3.3
# 19                0.714                    24.2                   10.4
# 20                0.510                    12.9                    3.7
# 21                0.780                    10.9                    3.5
# 22                0.724                     6.7                    3.7
# 23                0.834                    16.5                    6.1
# 24                0.600                     5.1                    2.2
# 25                0.500                     5.7                    1.6
# 26                0.639                    18.7                    6.0
# 27                0.766                    19.9                    8.7
# 28                0.708                    17.4                    6.6
# 29                0.400                     7.0                    1.8
# 30                0.640                    12.1                    4.3
# 31                0.710                    12.6                    5.5
# 32                0.747                    11.3                    4.9
# 33                0.808                    21.1                    7.6
# 34                  NaN                     NaN                    NaN
# 35                0.872                    27.8                   11.3
# 36                1.000                    12.3                    3.0
# 37                0.775                    15.9                    4.0
# 38                  NaN                     NaN                    NaN
# 39                1.000                     3.4                    1.4
# 40                0.600                     5.7                    1.2
# 41                0.788                    20.5                    7.2
# 42                0.667                     6.9                    1.2
# 43                  NaN                     NaN                    NaN
# 44                0.500                     4.9                    1.3
# 45                0.450                     7.4                    2.2
# 46                0.750                     5.8                    1.6
# 47                0.758                    17.0                    4.7
# 48                1.000                     3.6                    0.4
# 49                0.750                     3.9                    0.9
# 50                  NaN                     3.3                    0.0
# 51                0.500                     5.1                    1.7
# 52                  NaN                     NaN                    NaN
# 53                0.754                     9.1                    3.8
# 54                1.000                     5.6                    2.4
# 55                  NaN                     4.7                    2.0
# 56                  NaN                     NaN                    NaN
# 57                0.590                    10.9                    3.0
# 58                  NaN                     NaN                    NaN
# 59                0.782                    28.4                    9.7
#
#     draft_TRB.per.game  draft_Assits.per.Game  draft_Win.Share  \
# 0                  8.1                    8.2              9.2
# 1                  4.6                    2.9              2.5
# 2                  3.8                    1.2              6.0
# 3                  3.7                    1.2             -0.3
# 4                  3.0                    3.8              1.0
# 5                  3.6                    1.7              4.1
# 6                  3.1                    2.7              6.9
# 7                  4.8                    0.9              2.5
# 8                  4.1                    0.5              7.2
# 9                  2.6                    0.5              2.8
# 10                 5.5                    1.5              5.5
# 11                 3.9                    1.9              3.1
# 12                 3.2                    0.7              0.4
# 13                 4.1                    2.3              3.1
# 14                 2.8                    0.5              2.2
# 15                 1.6                    0.5              0.6
# 16                 1.4                    1.7              0.0
# 17                 2.1                    0.5             -0.1
# 18                 1.0                    0.5              0.5
# 19                 3.5                    3.2              4.1
# 20                 2.0                    1.2             -0.1
# 21                 1.2                    0.5              0.0
# 22                 1.9                    0.2              1.0
# 23                 1.8                    1.1              1.6
# 24                 1.6                    0.1              0.1
# 25                 0.8                    0.3              0.0
# 26                 4.0                    1.3              6.2
# 27                 4.8                    1.1              2.6
# 28                 4.2                    2.3              3.2
# 29                 1.5                    0.1              0.1
# 30                 3.2                    0.4              3.2
# 31                 3.5                    0.7              2.1
# 32                 4.1                    0.3              2.4
# 33                 1.7                    4.1              0.5
# 34                 NaN                    NaN              NaN
# 35                 3.0                    3.8              6.9
# 36                 2.3                    0.7              0.1
# 37                 1.4                    1.2              2.3
# 38                 NaN                    NaN              NaN
# 39                 0.9                    0.0             -0.1
# 40                 1.8                    0.2              0.0
# 41                 2.4                    2.4             -0.9
# 42                 1.2                    0.1             -0.3
# 43                 NaN                    NaN              NaN
# 44                 0.8                    0.6              0.1
# 45                 1.6                    0.2              0.0
# 46                 0.6                    0.3             -0.3
# 47                 2.6                    0.8             -0.1
# 48                 0.3                    0.2             -0.1
# 49                 0.8                    0.3             -0.3
# 50                 0.7                    0.0             -0.1
# 51                 1.5                    0.1              0.3
# 52                 NaN                    NaN              NaN
# 53                 1.0                    1.3             -0.4
# 54                 0.8                    0.6              0.0
# 55                 0.8                    1.3              0.1
# 56                 NaN                    NaN              NaN
# 57                 1.5                    0.5             -0.1
# 58                 NaN                    NaN              NaN
# 59                 3.5                    2.4              0.7
#
#     draft_WS_per_game  draft_BPM  draft_VORP  nba_VORP
# 0               0.162        4.6         4.6       4.6
# 1               0.028       -2.6        -0.7       0.4
# 2               0.082       -1.6         0.3       1.0
# 3              -0.005       -3.0        -0.7      -0.4
# 4               0.016       -1.1         0.7       0.7
# 5               0.050       -1.4         0.6       0.9
# 6               0.076       -1.2         0.9       1.2
# 7               0.037       -1.8         0.2       0.0
# 8               0.161        2.2         2.3       2.0
# 9               0.074       -2.3        -0.1      -0.2
# 10              0.077       -2.4        -0.4       0.8
# 11              0.043       -1.2         0.7       0.8
# 12              0.044       -3.0        -0.1      -0.1
# 13              0.048       -1.2         0.6       0.8
# 14              0.093       -1.8         0.1      -0.1
# 15              0.122       -0.7         0.1       0.1
# 16             -0.004       -4.7        -0.3       0.0
# 17             -0.008       -7.3        -0.6      -0.4
# 18              0.034       -4.9        -0.5      -0.5
# 19              0.063       -0.8         1.0       0.7
# 20             -0.005       -4.4        -0.5      -0.3
# 21              0.001       -6.1        -0.5      -0.4
# 22              0.231        0.1         0.1       0.1
# 23              0.039       -4.3        -1.1      -0.5
# 24              0.062       -2.5         0.0       0.0
# 25             -0.006       -6.9        -0.1      -0.1
# 26              0.118        1.0         1.9       1.7
# 27              0.069       -2.6        -0.3      -0.2
# 28              0.074        0.3         1.2       1.4
# 29              0.025       -8.1        -0.3      -0.1
# 30              0.130       -1.5         0.2       0.3
# 31              0.099       -2.4        -0.1       0.0
# 32              0.145       -3.7        -0.3      -0.2
# 33              0.008       -4.7        -1.9      -1.3
# 34                NaN        NaN         NaN       NaN
# 35              0.096       -0.8         1.0       0.2
# 36              0.043       -4.1         0.0      -0.1
# 37              0.054       -2.6        -0.3      -0.3
# 38                NaN        NaN         NaN       NaN
# 39             -0.211      -24.1        -0.1       NaN
# 40             -0.005       -7.3        -0.1       NaN
# 41             -0.025       -4.9        -1.4      -0.2
# 42             -0.104       -7.2        -0.2      -0.2
# 43                NaN        NaN         NaN       NaN
# 44              0.029       -3.4         0.0      -0.1
# 45             -0.001       -5.6        -0.1       NaN
# 46             -0.041       -6.4        -0.5      -0.1
# 47             -0.002       -4.8        -1.2      -0.8
# 48             -0.136      -10.5        -0.1       NaN
# 49             -0.132      -10.0        -0.3       0.0
# 50             -0.473      -26.9        -0.1       NaN
# 51              0.132       -3.7         0.0      -0.1
# 52                NaN        NaN         NaN       NaN
# 53             -0.041       -7.7        -0.8      -0.4
# 54             -0.006       -6.9         0.0       0.0
# 55              0.169       -1.6         0.0       0.0
# 56                NaN        NaN         NaN       NaN
# 57             -0.014       -5.6        -0.5      -0.5
# 58                NaN        NaN         NaN       NaN
# 59              0.042       -2.0         0.0       0.0
#
# [60 rows x 24 columns]

# %%
input_list = sel_var
input_list.extend(('draft_Player', 'nba_VORP'))
new_draft = new_draft[input_list].dropna(axis=0, how='any')

# %%
X_new = new_draft.drop(['nba_VORP', 'draft_Player'], axis=1)
y_new = new_draft['nba_VORP']

# %%
classifier = pickle.load(open("VORPRegression_Model.pkl", "rb"))

# %%
new_predicted_vorp = classifier.predict(X_new)
predict_comp = pd.DataFrame({"Predicted Vorp": new_predicted_vorp, "nba_VORP (Actual)": y_new})

# %%
new_predicted_vorp = pd.DataFrame(clf2.predict(X2))
predicted_vorp.columns = ['Predicted_VORP']
pred_feat = clean_data1[sel_var]
player = clean_data1['draft_Player']
actual_vorp = clean_data['nba_VORP']
vorp_diff = actual_vorp - predicted_vorp
prediction_df = pd.concat([player, pred_feat, actual_vorp, predicted_vorp], axis=1)
prediction_df["Predicted_VORP"] = prediction_df['Predicted_VORP'].round(1)
prediction_df["VORP_diff"] = (prediction_df["nba_VORP"]-prediction_df["Predicted_VORP"])
prediction_df["Abs_diff"] = np.abs(prediction_df['VORP_diff'])
prediction_df.head()

# %%
#Going with correlation data 
#Scale the data and predict
X = clean_data[sel_var]
y = clean_data["nba_VORP"]

# %%
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics
X = clean_data[sel_var]
y = clean_data["nba_VORP"]
prediction = cross_val_predict(reg2, X, y, cv=6)
print ("Cross-validated scores:", prediction)

# %%
plt.scatter(y, prediction)

# %%
#How accurate is the model:
score = metrics.r2_score(y,predicted)
print ("Cross-Predicted Score:", score)
